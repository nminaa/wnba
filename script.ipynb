# %%
"""
Author: Madison Sanchez-Forman
Version: 11.6.24
Description: This notebook will make requests to an API that contains WNBA data. 
Field Ideas: 
	location, team name, roster, ranking(through time), 
    roster (just this years), game schedule, draft data (through time), play by play
"""
import requests
import pandas as pd

url = "https://wnba-api.p.rapidapi.com/team-roster"
querystring = {"teamId":"16"}

headers = {
	"x-rapidapi-key": "bbab47d613mshc6d4bd010325bd8p15a54bjsn74ce75016aad",
	"x-rapidapi-host": "wnba-api.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
resppnse_dictionary = dict(response.json())
df = pd.json_normalize(resppnse_dictionary['data'])

print(df.describe())
print(df.head(10))
print(df.columns)
# print(df.head())
# Out:
#            weight     height        age  experience.years
# count   10.000000  12.000000  12.000000         12.000000
# mean   169.100000  72.000000  26.500000          3.416667
# std     29.072515   3.357488   3.729489          3.423404
# min    140.000000  68.000000  22.000000          0.000000
# 25%    147.250000  69.000000  23.500000          0.750000
# 50%    163.500000  71.500000  26.500000          2.000000
# 75%    180.000000  75.000000  29.250000          6.250000
# max    235.000000  77.000000  32.000000         10.000000
#   playerId                  uid firstName   lastName          fullName  \
# 0  3146151  s:40~l:59~a:3146151     Ariel     Atkins      Ariel Atkins
# 1  4398911  s:40~l:59~a:4398911   Shakira     Austin    Shakira Austin
# 2  2529183  s:40~l:59~a:2529183  Stefanie     Dolson   Stefanie Dolson
# 3  4433408  s:40~l:59~a:4433408   Aaliyah    Edwards   Aaliyah Edwards
# 4  4398729  s:40~l:59~a:4398729     Emily   Engstler    Emily Engstler
# 5  5017721  s:40~l:59~a:5017721      Sika       Kone         Sika Kone
# 6  5017726  s:40~l:59~a:5017726      Jade  Melbourne    Jade Melbourne
# 7  3056730  s:40~l:59~a:3056730    Karlie  Samuelson  Karlie Samuelson
# 8  4068159  s:40~l:59~a:4068159       Sug     Sutton        Sug Sutton
# 9  2988756  s:40~l:59~a:2988756  Brittney      Sykes    Brittney Sykes
#
#         displayName     shortName  weight displayWeight  height  ...  \
# 0      Ariel Atkins     A. Atkins   167.0       167 lbs      70  ...
# 1    Shakira Austin     S. Austin   190.0       190 lbs      77  ...
# 2   Stefanie Dolson     S. Dolson   235.0       235 lbs      77  ...
# 3   Aaliyah Edwards    A. Edwards     NaN                    75  ...
# 4    Emily Engstler   E. Engstler   180.0       180 lbs      73  ...
# 5         Sika Kone       S. Kone   180.0       180 lbs      75  ...
# 6    Jade Melbourne  J. Melbourne   145.0       145 lbs      71  ...
# 7  Karlie Samuelson  K. Samuelson   160.0       160 lbs      72  ...
# 8        Sug Sutton     S. Sutton   140.0       140 lbs      68  ...
# 9    Brittney Sykes      B. Sykes   154.0       154 lbs      69  ...
#
#   college.name  college.shortName college.abbrev  \
# 0        Texas              Texas            TEX
# 1     Ole Miss           Ole Miss           MISS
# 2        UConn              UConn           CONN
# 3        UConn              UConn           CONN
# 4   Louisville         Louisville            LOU
# 5
# 6
# 7     Stanford           Stanford           STAN
# 8        Texas              Texas            TEX
# 9     Syracuse           Syracuse            SYR
#
#                                         college.logo position.id  \
# 0  https://a.espncdn.com/i/teamlogos/ncaa/500/251...           3
# 1  https://a.espncdn.com/i/teamlogos/ncaa/500/145...           9
# 2  https://a.espncdn.com/i/teamlogos/ncaa/500/41.png           9
# 3  https://a.espncdn.com/i/teamlogos/ncaa/500/41.png           7
# 4  https://a.espncdn.com/i/teamlogos/ncaa/500/97.png           7
# 5                                                              7
# 6                                                              3
# 7  https://a.espncdn.com/i/teamlogos/ncaa/500/24.png           3
# 8  https://a.espncdn.com/i/teamlogos/ncaa/500/251...           3
# 9  https://a.espncdn.com/i/teamlogos/ncaa/500/183...           3
#
#   position.name position.displayName position.abbreviation position.leaf  \
# 0         Guard                Guard                     G         False
# 1        Center               Center                     C         False
# 2        Center               Center                     C         False
# 3       Forward              Forward                     F         False
# 4       Forward              Forward                     F         False
# 5       Forward              Forward                     F         False
# 6         Guard                Guard                     G         False
# 7         Guard                Guard                     G         False
# 8         Guard                Guard                     G         False
# 9         Guard                Guard                     G         False
#
#   experience.years
# 0                6
# 1                2
# 2               10
# 3                0
# 4                2
# 5                1
# 6                1
# 7                5
# 8                0
# 9                7
#
# [10 rows x 35 columns]
# Index(['playerId', 'uid', 'firstName', 'lastName', 'fullName', 'displayName',
#        'shortName', 'weight', 'displayWeight', 'height', 'displayHeight',
#        'age', 'dateOfBirth', 'links', 'slug', 'headshot', 'jersey', 'injuries',
#        'contracts', 'status', 'birthPlace.city', 'birthPlace.state',
#        'birthPlace.country', 'college.collegeId', 'college.mascot',
#        'college.name', 'college.shortName', 'college.abbrev', 'college.logo',
#        'position.id', 'position.name', 'position.displayName',
#        'position.abbreviation', 'position.leaf', 'experience.years'],
#       dtype='object')
